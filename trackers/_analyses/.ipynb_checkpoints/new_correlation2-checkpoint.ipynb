# %%
import json
import csv
import pandas as pd
from pandas import DataFrame, Series
import dateutil.parser
from dateutil.tz import gettz
import datetime
import pytz
from functools import reduce
import time
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import calendar
from time import mktime
from datetime import datetime
import matplotlib
import matplotlib.pyplot as plt

# %%
# time format conversions

# def roundUnixTime(timestamp):
#     timestamp = timestamp - (timestamp % 3600)
#     return timestamp

def convertUTCToTimestamp(timestamp):
    nanosecondTimestamp = timestamp * 1e9
    timestamp = pd.Timestamp(nanosecondTimestamp, tz='US/Eastern')
    return timestamp

def convertTimeToStruct(timestamp):
    timestamp = time.gmtime(timestamp)
    return timestamp

# %%
# mood reporter data

responsesDF = pd.read_csv("../reporter/responses.tsv", sep='\t', header=0, true_values=['true', 'True', 'tru'], false_values=['false', 'False'])

timeValues = responsesDF.unix_time.values

# create DF columns for each unique activity and location entry
activity_names = list(set(list(map(lambda x: x.lower().strip(), reduce(lambda x,y: x+y, [x.split(",") for x in list(responsesDF.activity.values)])))))

for activity_name in activity_names:
    responsesDF[activity_name.replace(" ", "_") + "_activity"] = responsesDF.activity.apply(lambda x: activity_name in x.lower())

location_names = list(set(list(map(lambda x: x.lower().strip(), reduce(lambda x,y: x+y, [x.split(",") for x in list(responsesDF.location.values)])))))

def split_locations(locations):
    return list(map(lambda x: x.lower().strip(), locations.split(",")))

for location_name in location_names:
    responsesDF[location_name.replace(" ", "_") + "_location"] = responsesDF.location.apply(lambda x: location_name in split_locations(x))

responsesDF.time = responsesDF.unix_time

# delete redundant columns
del responsesDF['moodNotes']
del responsesDF['trigger']
del responsesDF['activity']
del responsesDF['location']
del responsesDF['unix_time']


responsesDF.time = responsesDF.time.apply(convertUTCToTimestamp)

# %%
#keylogger data

tone_names = ['Sadness', 'Analytical', 'Joy', 'Fear', 'Tentative', 'Anger', 'Confident']

with open('../keylogger/logs/log_new.json', 'r') as f:
    keyloggerData = json.load(f)

# tzinfos = { "EDT" : gettz("America/New_York") }


# format data
def extract_keyloggerData(data):
    keyloggerResults = []
    keystrokeWordCountResults = []

    for d in data:
        # create columns for each IBM Tone Analyzer sentiment
        keyloggerResult = [0] * (len(tone_names)+1)
        # create columns for my text analysis/keystroke dynamics metrics
        keystrokeWordCountResult = [0] * 6
        
        # add present sentiment scores to keyloggerResult array; absent sentiments remain at 0
        tones = d['document_tone']['tones']
        for i in range(len(tones)):
            score = tones[i]['score']
            tone_name = tones[i]['tone_name']
            tone_index = tone_names.index(tone_name)
            keyloggerResult[tone_index] = score            

        keyloggerResult[-1] = d['unix_time']

        keyloggerResults.append(tuple(keyloggerResult))
        
        # text analysis/keystroke dynamics were added a couple months later
        try:
            keystrokeWordCountResult[0] = d['word_count']
            keystrokeWordCountResult[1] = d['uniqueword_ratio']
            keystrokeWordCountResult[2] = d['backspace_count']
            keystrokeWordCountResult[3] = d['avg_dwelltime']
            keystrokeWordCountResult[4] = d['avg_flighttime']
            keystrokeWordCountResult[5] = d['unix_time']
            
            keystrokeWordCountResults.append(tuple(keystrokeWordCountResult))
            
        except:
            continue
            
    return keyloggerResults, keystrokeWordCountResults

both = extract_keyloggerData(keyloggerData)

# dataframe for IBM Tone Analyzer scores
keyloggerDF = DataFrame(both[0],
                        columns=[tone_name+"_score" for tone_name in tone_names] + ['time'])

# dataframe for text analysis/keystroke dynamics
keystrokeWordCountDF = DataFrame(both[1],
                        columns=['word_count', 'uniqueword_ratio', 'backspace_count', 'avg_dwelltime', 'avg_flighttime', 'time'])

keyloggerDF.time = keyloggerDF.time.apply(convertUTCToTimestamp)
keyloggerDF.sort_values('time', inplace=True)

keystrokeWordCountDF.time = keystrokeWordCountDF.time.apply(convertUTCToTimestamp)
keystrokeWordCountDF.sort_values('time', inplace=True)

# %%
#affectiva data


with open('../getAPIdata/merged_file.json', 'r') as f:
    affectivaData = json.load(f)

for x in range(0, len(affectivaData)):
    # convert timestamp to miliseconds
    affectivaData[x]['time'] = affectivaData[x]['time']/ 1e3
    # count number of expressions for each hour
    affectivaData[x]['emoji'] = len(affectivaData[x]['emoji'])


affectivaDF = DataFrame(affectivaData)

# delete redundant columns
del affectivaDF['emotions']
del affectivaDF['max_attention']
del affectivaDF['min_attention']
del affectivaDF['max_engagement']
del affectivaDF['min_engagement']
del affectivaDF['max_valence']
del affectivaDF['min_valence']

affectivaDF.time = affectivaDF.time.apply(convertUTCToTimestamp)
affectivaDF.sort_values('time', inplace=True)

# %%
#rescuetime data

from dateutil import parser
import calendar

with open('../getAPIdata/productivity.json', 'r') as f:
    productivityFile = json.load(f)

productivityData = productivityFile['rows']

final_productivityData = [];
UTC = pytz.timezone('UTC')

#convert timestamp string (local time) to structured time object (UTC)
for x in range(0, len(productivityData)):
    date = parser.parse(productivityData[x][0])
    dateutc = str(date.astimezone(UTC))
    dateutc2 = dateutc[:19] + "UTC"
    newtime = time.strptime(dateutc2, "%Y-%m-%d %H:%M:%S%Z")
    finalTime = calendar.timegm(newtime)
    
    # extract productivity score
    prod_score = productivityData[x][4]
    final_productivityData.append((finalTime, prod_score))

productivityDF = DataFrame(final_productivityData, columns=['time', 'productivity_score'])
productivityDF.time = productivityDF.time.apply(convertUTCToTimestamp)

productivityDF.sort_values('time', inplace=True)

# %%
#quality time app data

qualityTimeDF = pd.read_csv("../QualityTime/1543959637913_ENTIRE_HISTORY_1480887628603_1543959628603.csv", header=0)
qtTimeVals = qualityTimeDF.End_Time.values

#convert timestamp to miliseconds
newQTtimeVals = []
for x in range(0, len(qtTimeVals)):
    timestamp = time.gmtime(int(qtTimeVals[x]) / 1e3)
    newQTtimeVals.append(timestamp)

# extract time usage data
usageVals = qualityTimeDF.Usage.values
newQTusageVals = []

# if usage data is in hours and/or minutes, convert into seconds
for x in range(0, len(usageVals)):
    string = usageVals[x]
    minSubstring = "min"
    hrSubstring = "hr"
    finalSecs = 0
    
    if hrSubstring in string:
        removeHr = string[0:1]
        newHr = int(removeHr) * 3600
        finalSecs += newHr
    elif minSubstring in string:
        removeMin = string[-6:-4]
        newMin = int(removeMin) * 60
        finalSecs += newMin
    else:
        removeSec = string[0:-4]
        newSec = int(removeSec)
        finalSecs += newSec
        
    newQTusageVals.append(finalSecs)

# sub in new time and usage values
qualityTimeDF.End_Time = newQTtimeVals
qualityTimeDF.Usage = newQTusageVals

# keep only time and usage columns
qualityTimeDF = qualityTimeDF[['End_Time', 'Usage']]
qualityTimeDF.columns = ['time', 'usage_in_sec']

# combine time entries and their usage values into their respective one hour chunks
compressed = []
current_hour = qualityTimeDF['time'][0]
total_usage = 0
unlocks = 0

for index, row in qualityTimeDF.iterrows():
    if (index == len(qualityTimeDF) -1):
        holder = [0] * 3
        holder[0] = current_hour
        holder[1] = unlocks
        holder[2] = total_usage
        compressed.append(tuple(holder))
    elif (row['time'].tm_year == current_hour.tm_year and row['time'].tm_mon == current_hour.tm_mon and row['time'].tm_mday == current_hour.tm_mday and row['time'].tm_hour == current_hour.tm_hour):
        total_usage += row['usage_in_sec']
        unlocks +=1
    else:
        holder = [0] * 3
        holder[0] = current_hour
        holder[1] = unlocks
        holder[2] = total_usage
        compressed.append(tuple(holder))
        total_usage = 0
        unlocks = 0
        current_hour = row['time']
        total_usage += row['usage_in_sec']
        unlocks +=1
        
# new dataframe for compressed data
newQTDF = DataFrame(compressed, columns = ['time', 'phone_unlocks', 'phone_use_secs'])
newQTDF.time = newQTDF.time.apply(mktime)
newQTDF.time = newQTDF.time.apply(convertUTCToTimestamp)

newQTDF.sort_values('time', inplace=True)

# %%
# google fit data

with open('../google_fit/dataset.json', 'r') as f:
    fitData = json.load(f)

# combine time entries and their step counts into one hour chunks
stepCountCompressed = []

def extract_fitData(fitData):
    current_timestamp = int(fitData[0]['endTimeNanos']) / 1e9
    current_hour = convertTimeToStruct(int(fitData[0]['endTimeNanos']) / 1e9)
    stepCount = 0

    for d in fitData:
        dHour = convertTimeToStruct(int(d['endTimeNanos']) / 1e9)
        if (dHour.tm_year == current_hour.tm_year and dHour.tm_mon == current_hour.tm_mon and dHour.tm_mday == current_hour.tm_mday and dHour.tm_hour == current_hour.tm_hour):
            stepCount += int(d['value'][0]['intVal'])
        else:
            holder = [0] * 2
            holder[0] = current_timestamp
            holder[1] = stepCount
            
            stepCountCompressed.append(tuple(holder))
            stepCount = 0

            current_hour = convertTimeToStruct(int(d['endTimeNanos']) / 1e9)
            current_timestamp = int(d['endTimeNanos']) / 1e9

            stepCount += int(d['value'][0]['intVal'])


extract_fitData(fitData['point'])

stepCountDF = DataFrame(stepCountCompressed, columns = ['time', 'stepCount'])

stepCountDF.time = stepCountDF.time.apply(convertUTCToTimestamp)
stepCountDF.sort_values('time', inplace=True)

# %%
#tabcounter data

with open('../getAPIdata/chromeactivity.json', 'r') as f:
    tabCounterData = json.load(f)

newTabData = []

# get values for each key in json, build new dataframe
for key in tabCounterData:
    timestamp = int(key) / 1e3

    current_tabCount = tabCounterData[key]['current_tabCount']
    current_windowCount = tabCounterData[key]['current_windowCount']
    tabs_activated = tabCounterData[key]['tabs_activated']
    tabs_created = tabCounterData[key]['tabs_created']
    windows_created = tabCounterData[key]['windows_created']

    newTabData.append([timestamp, current_tabCount, current_windowCount,tabs_activated,tabs_created,windows_created])

tabColumns = ['time', 'current_tabCount', 'current_windowCount','tabs_activated','tabs_created','windows_created']
tabCounterDF = DataFrame(newTabData, columns=tabColumns)

tabCounterDF.time = tabCounterDF.time.apply(convertUTCToTimestamp)

tabCounterDF.sort_values('time', inplace=True)

# %%
# heart rate data

heartRateDF = pd.read_csv("../webcam-pulse-detector-no_openmdao/heartRate.csv", sep=',', header=0)

heartRateDF.time = heartRateDF.time.apply(convertUTCToTimestamp)
heartRateDF.sort_values('time', inplace=True)
heartRateDF = heartRateDF.reset_index(drop=True)

# %%
# create dataframe of hour of day (from mood reporter)

def hourOnly(timestamp):
    timestamp = timestamp.hour
    return timestamp


hourColumn = pd.to_datetime(responsesDF.time, unit='s')
hourDF = DataFrame(hourColumn)
hourDF.sort_values('time', inplace=True)
hourDF['hour'] = hourDF.time.apply(hourOnly)

# %%
# merge all dataframes on nearest timestamp

mergedDF1 = pd.merge_asof(keyloggerDF, keystrokeWordCountDF, on='time', direction='nearest', tolerance=pd.Timedelta('1 hours')).dropna()
mergedDF1.reset_index(inplace=True)
del mergedDF1['index']

mergedDF2 = pd.merge_asof(affectivaDF, mergedDF1, on='time', direction='nearest', tolerance=pd.Timedelta('1.5 hours')).dropna()
mergedDF2.reset_index(inplace=True)
del mergedDF2['index']

mergedDF3 = pd.merge_asof(mergedDF2, stepCountDF, on='time', direction='nearest', tolerance=pd.Timedelta('2 hours')).fillna(0)
mergedDF3.reset_index(inplace=True)
del mergedDF3['index']

mergedDF4 = pd.merge_asof(mergedDF3, tabCounterDF, on='time', direction='nearest', tolerance=pd.Timedelta('1.5 hours')).dropna()
mergedDF4.reset_index(inplace=True)
del mergedDF4['index']

mergedDF5 = pd.merge_asof(mergedDF4, productivityDF, on='time', direction='nearest', tolerance=pd.Timedelta('1.5 hours')).dropna()
mergedDF5.reset_index(inplace=True)
del mergedDF5['index']

mergedDF6 = pd.merge_asof(mergedDF5, newQTDF, on='time', direction='nearest', tolerance=pd.Timedelta('1.5 hours')).dropna()
mergedDF6.reset_index(inplace=True)
del mergedDF6['index']

mergedDF7 = pd.merge_asof(mergedDF6, heartRateDF, on='time', direction='nearest', tolerance=pd.Timedelta('2 hours')).dropna()
mergedDF7.reset_index(inplace=True)
del mergedDF7['index']

mergedDF8 = pd.merge_asof(responsesDF, hourDF, on='time', direction='nearest', tolerance=pd.Timedelta('1 hours')).dropna()
mergedDF8.reset_index(inplace=True)
del mergedDF8['index']

finalMergedDF = pd.merge_asof(mergedDF8, mergedDF7, on='time', direction='nearest', tolerance=pd.Timedelta('1.5 hours')).dropna()
finalMergedDF.reset_index(inplace=True)
del finalMergedDF['index']

finalMergedDF
# Out:
#                                    time  mood  unique_interactions  alone  \
# 0   2018-06-02 19:08:28.065821184-04:00   3.0                    1   True
# 1   2018-06-02 20:19:14.888844032-04:00   3.0                    0   True
# 2   2018-06-02 21:25:25.471260160-04:00   3.0                    0   True
# 13            12.0           844.0    74.000000
# 14             7.0          1431.0    74.000000
# 15             7.0           493.0    78.000000
# 16             3.0            72.0    72.000000
# 17             3.0            72.0    72.000000
# 18             3.0            72.0    72.000000
# 19            18.0           298.0    87.000000
# 20            33.0          1554.0    87.000000
# 21            33.0          1554.0    87.000000
# 22            19.0           401.0    82.000000
# 23            19.0           401.0    82.000000
# 24            19.0           401.0    82.000000
# 25             7.0           398.0    76.000000
# 26             7.0           398.0    77.000000
# 27             7.0           165.0    76.000000
# 28            13.0           233.0    75.000000
# 29             2.0            39.0    73.000000
# ..             ...             ...          ...
# 683            3.0            68.0    66.960537
# 684           13.0           779.0    75.744686
# 685           13.0           779.0    75.744686
# 686            1.0            60.0    57.349433
# 687            1.0            60.0    57.349433
# 688            7.0           302.0    75.547910
# 689           10.0           269.0    61.074964
# 690           10.0           269.0    59.354449
# 691           10.0           269.0    59.354449
# 692           15.0           270.0    59.870685
# 693           25.0           492.0    80.884079
# 694           18.0           640.0    67.671883
# 695            1.0             2.0    70.349228
# 696            2.0            32.0    62.791659
# 697           10.0           242.0    58.475071
# 698           10.0           242.0    75.834588
# 699            3.0           209.0    61.699871
# 700            4.0            62.0    72.030712
# 701            4.0            62.0    72.314717
# 702            3.0            50.0    70.541487
# 703            3.0            35.0    74.646085
# 704            2.0            12.0    54.939316
# 705           26.0           947.0    58.235859
# 706           26.0           947.0    58.235859
# 707            1.0             6.0    59.907418
# 708           16.0           206.0    68.120395
# 709            5.0           110.0    62.832344
# 710            4.0            40.0    72.339379
# 711            2.0            18.0    61.882339
# 712            2.0            18.0    61.882339
#
# [713 rows x 87 columns]

# %%
# del finalMergedDF['time']
# finalMergedDF.to_csv("mergedDF.tsv", sep='\t', encoding='utf-8')

# %%
# from sklearn.externals import joblib
# joblib.dump(finalMergedDF, '/Users/jxu2/github/thesis_explorations/life_support/predictor/finalMergedDF.pkl')

# %%
finalMergedDF['alone'] = finalMergedDF['alone'].astype('bool')

finalMergedDF
# Out:
#                                    time  mood  unique_interactions  alone  \
# 0   2018-06-02 19:08:28.065821184-04:00   3.0                    1   True
# 1   2018-06-02 20:19:14.888844032-04:00   3.0                    0   True
# 2   2018-06-02 21:25:25.471260160-04:00   3.0                    0   True
# 3   2018-06-02 22:25:59.244112896-04:00   2.5                    0   True
# 4   2018-06-02 23:26:34.387373056-04:00   3.0                    0   True
# 5   2018-06-03 15:01:05.512634880-04:00   3.5                    2   True
# 6   2018-06-03 16:05:10.222202112-04:00   3.5                    0   True
# 7   2018-06-03 17:06:07.752846848-04:00   3.5                    0   True
# 8   2018-06-03 21:33:15.274811136-04:00   2.0                    2   True
# 9   2018-06-03 22:34:50.265445120-04:00   2.5                    1   True
# 10  2018-06-03 23:36:03.059630080-04:00   2.5                    0   True
# 11  2018-06-04 13:07:09.689389824-04:00   3.0                    1   True
# 12  2018-06-04 14:10:16.359375872-04:00   3.0                    0   True
# 13  2018-06-04 15:11:17.590006016-04:00   3.5                    1   True
# 14  2018-06-04 16:12:55.318465024-04:00   3.5                    2   True
# 712 2018-12-04 23:35:06.218309888-05:00   2.5                    1   True
#
#      morale  stress  fatigue  compulsions  getting_ready_activity  _activity  \
# 0       2.5     1.0      1.0        False                   False       True
# 1       3.0     0.0      1.5        False                   False       True
# 2       2.5     0.0      1.5         True                   False       True
# 3       2.0     0.0      2.0         True                   False       True
# 4       3.0     0.0      2.5        False                   False       True
# 5       3.5     0.0      1.5        False                   False       True
# 6       3.5     0.0      2.0         True                   False       True
# 7       4.0     0.5      2.0        False                   False       True
# 8       2.0     3.0      4.0        False                   False       True
# 9       2.0     0.0      4.5         True                   False       True
# 10      1.5     0.5      4.5        False                   False       True
# 11      2.5     0.5      1.5        False                   False       True
# 12      3.0     0.0      1.5         True                   False       True
# 13      4.0     0.0      2.0        False                   False       True
# 14      3.0     1.5      2.0        False                   False       True
# 15      3.0     0.5      1.5        False                   False       True
# 16      3.0     0.5      2.5        False                   False       True
# 17      3.0     0.5      2.5        False                   False       True
# 18      3.0     0.5      3.0        False                   False       True
# 19      2.0     0.5      4.0        False                   False       True
# 20      1.0     0.0      4.5        False                   False       True
# 21      1.0     0.0      4.5        False                   False       True
# 22      2.0     0.0      4.5        False                   False       True
# 23      2.0     0.0      4.5         True                   False       True
# 24      1.0     0.0      4.5         True                   False       True
# 25      2.0     1.0      4.5        False                   False       True
# 26      1.0     0.5      5.0        False                   False       True
# 27      3.0     0.0      1.5        False                   False       True
# 28      3.0     0.0      3.0         True                   False       True
# 29      2.5     1.0      4.0         True                   False       True
# ..      ...     ...      ...          ...                     ...        ...
# 683     3.0     3.0      4.0        False                   False       True
# 684     2.5     3.5      4.5        False                   False       True
# 685     3.0     3.0      5.0        False                   False       True
# 686     3.0     0.5      4.0         True                   False       True
# 687     2.5     1.0      4.0         True                   False       True
# 688     4.5     3.0      3.5        False                   False       True
# 689     3.5     2.0      4.0        False                   False       True
# 690     2.5     1.5      4.0         True                   False       True
# 691     2.5     1.5      3.5         True                   False       True
# 692     2.5     1.0      3.5         True                   False       True
# 693     3.0     0.5      3.0        False                   False       True
# 694     3.5     1.0      3.0        False                   False       True
# 695     2.5     1.5      4.0         True                   False       True
# 696     2.5     2.5      4.5        False                   False       True
# 697     3.0     2.0      2.5        False                   False       True
# 698     2.5     2.5      3.0        False                   False       True
# 699     2.5     2.5      3.0        False                   False       True
# 700     3.0     2.0      2.5        False                   False       True
# 701     3.0     1.5      2.0         True                   False       True
# 702     3.0     1.0      3.0         True                   False       True
# 703     2.5     0.5      3.5         True                   False       True
# 704     2.5     0.5      4.0         True                   False       True
# 705     3.0     1.0      3.0        False                   False       True
# 706     3.0     1.5      2.5         True                   False       True
# 707     3.5     2.0      3.0         True                   False       True
# 708     3.5     1.5      3.0        False                   False       True
# 709     3.5     1.0      3.5        False                   False       True
# 710     3.0     1.5      3.5        False                   False       True
# 711     3.0     1.0      3.5         True                   False       True
# 712     2.5     1.5      4.0         True                   False       True
#
#         ...       stepCount  current_tabCount  current_windowCount  \
# 0       ...            10.0              25.0                  2.0
# 1       ...            10.0              23.0                  2.0
# Anger_score                   0.002963             0.087625 -0.017505
# Confident_score              -0.014498            -0.060649  0.015539
# word_count                    0.007880             0.078782 -0.011728
# uniqueword_ratio             -0.030555            -0.043576  0.004989
# backspace_count               0.028994             0.006712 -0.051316
# avg_dwelltime                 0.020564            -0.091724  0.015750
# avg_flighttime               -0.029732            -0.142618  0.014149
# stepCount                     0.111163             0.094667 -0.107026
# current_tabCount              0.097088             0.065483 -0.034602
# current_windowCount           0.097914             0.083405 -0.012526
# tabs_activated                0.027906             0.077002 -0.133407
# tabs_created                 -0.001878            -0.020348  0.000719
# windows_created              -0.040939            -0.050563  0.016758
# productivity_score            0.056426            -0.063993 -0.132322
# phone_unlocks                -0.036622             0.012385  0.002791
# phone_use_secs                0.002816            -0.027687  0.006574
#  heart_rate                  -0.191944            -0.129654  0.085990
#
#                                 morale    stress   fatigue  compulsions  \
# mood                          0.641701 -0.154322 -0.261635    -0.171356
# unique_interactions           0.194102  0.061789 -0.115869    -0.035288
# alone                        -0.218468 -0.082821  0.181352     0.146464
# morale                        1.000000 -0.056362 -0.424740    -0.149429
# stress                       -0.056362  1.000000  0.153058     0.024964
# fatigue                      -0.424740  0.153058  1.000000     0.104736
# compulsions                  -0.149429  0.024964  0.104736     1.000000
# getting_ready_activity       -0.027349  0.037136 -0.009976     0.046783
# _activity                     0.000000  0.000000  0.000000     0.000000
# relaxing_activity             0.000000  0.000000  0.000000     0.000000
# just_woke_up_activity         0.000000  0.000000  0.000000     0.000000
# in_class_activity             0.120707  0.049107 -0.076426    -0.089147
# with_k_activity               0.128740 -0.113532 -0.131108     0.033078
# with_friends_activity         0.122168 -0.050591 -0.110052    -0.121463
# chatting_activity            -0.072605 -0.029360 -0.015087    -0.022448
# emails_activity               0.000000  0.000000  0.000000     0.000000
# leisure_activity             -0.333430 -0.188036  0.130438     0.080129
# with_parents_activity         0.000000  0.000000  0.000000     0.000000
# resting_activity              0.021693  0.006202  0.025110     0.014552
# trying_to_leave_apt_activity  0.000000  0.000000  0.000000     0.000000
# eating_activity               0.104395  0.020006 -0.140784    -0.098678
# therapy_activity              0.014950 -0.042521 -0.025078    -0.006673
# working_out_activity          0.002098  0.037026  0.000226    -0.060417
# feedly_activity              -0.164523 -0.062302  0.021628     0.017415
# working_activity              0.001917  0.142837  0.021958    -0.022042
# mozfest_activity              0.040453 -0.030046 -0.017721     0.033057
# ash_stuff_activity            0.007077 -0.041527 -0.156508     0.054658
# reading_activity             -0.070144 -0.000059  0.065551     0.074126
# schoolwork_activity           0.234184  0.128350  0.020218     0.006202
# email_activity                0.078069  0.053986 -0.047140     0.005926
# ...                                ...       ...       ...          ...
# london_location               0.023972 -0.070834  0.102111     0.087887
# library_location              0.050497 -0.033716 -0.068451    -0.027512
# hour                          0.054326  0.004093 -0.257801    -0.004274
# avg_attention                -0.053695 -0.023988  0.025160     0.023269
# avg_engagement                0.076734 -0.080200 -0.033525    -0.027355
# avg_valence                   0.012442 -0.032823  0.046064    -0.021771
# blinks                        0.053157  0.052137 -0.028544    -0.063661
# emoji                         0.063217 -0.081407 -0.083951    -0.058993
# Sadness_score                -0.096190  0.082485  0.100359     0.095943
# Analytical_score              0.087257  0.063425 -0.041673    -0.050389
# Joy_score                     0.119999 -0.075284 -0.056826    -0.034522
# Fear_score                   -0.065609  0.037611  0.124639    -0.043067
# Tentative_score              -0.043523 -0.005851  0.023313     0.047126
# Anger_score                   0.045334  0.106897  0.068579    -0.034824
# Confident_score              -0.036040 -0.034360 -0.000762     0.014796
# word_count                    0.036461  0.084890  0.018600     0.011387
# uniqueword_ratio             -0.144814 -0.098857  0.017632     0.041806
# backspace_count               0.113553  0.076908 -0.040271     0.013029
# avg_dwelltime                 0.113907  0.038171 -0.074000    -0.060394
# avg_flighttime                0.025142 -0.007912 -0.065296    -0.040793
# stepCount                     0.091904 -0.022510 -0.139097    -0.075882
# current_tabCount              0.109408  0.519490  0.107679     0.008668
# current_windowCount           0.098744  0.523248  0.118265     0.007243
# tabs_activated                0.051006  0.130175  0.050099    -0.075840
# tabs_created                  0.037564  0.110052  0.057976    -0.095406
# windows_created               0.004841  0.124435  0.030449     0.024913
# productivity_score            0.207960  0.106030 -0.048829     0.010102
# phone_unlocks                -0.089859 -0.129279  0.116100    -0.046420
# phone_use_secs               -0.048098 -0.093013  0.097519     0.003903
#  heart_rate                  -0.171383 -0.339008 -0.006276     0.066405
#
#                               getting_ready_activity  _activity  \
# mood                                       -0.030056        0.0
# unique_interactions                        -0.034860        0.0
# alone                                       0.036130        0.0
# morale                                     -0.027349        0.0
# stress                                      0.037136        0.0
# fatigue                                    -0.009976        0.0
# compulsions                                 0.046783        0.0
# getting_ready_activity                      1.000000        0.0
# _activity                                   0.000000        0.0
# relaxing_activity                           0.000000        0.0
# just_woke_up_activity                       0.000000        0.0
# in_class_activity                          -0.015782        0.0
# with_k_activity                            -0.006326        0.0
# with_friends_activity                      -0.018184        0.0
# chatting_activity                          -0.009464        0.0
# emails_activity                             0.000000        0.0
# leisure_activity                           -0.039575        0.0
# with_parents_activity                       0.000000        0.0
# resting_activity                           -0.007228        0.0
# trying_to_leave_apt_activity                0.000000        0.0
# eating_activity                            -0.019642        0.0
# therapy_activity                           -0.002813        0.0
# working_out_activity                       -0.006939        0.0
# feedly_activity                            -0.015182        0.0
# working_activity                           -0.012050        0.0
# mozfest_activity                           -0.001988        0.0
# ash_stuff_activity                         -0.011497        0.0
# reading_activity                           -0.004457        0.0
# schoolwork_activity                        -0.055865        0.0
# email_activity                             -0.011684        0.0
# ...                                              ...        ...
# london_location                            -0.008535        0.0
# library_location                           -0.004457        0.0
# hour                                       -0.018616        0.0
# avg_attention                               0.013288        0.0
# avg_engagement                              0.000182        0.0
# avg_valence                                 0.003673        0.0
# blinks                                      0.116599        0.0
# emoji                                       0.024105        0.0
# Sadness_score                               0.016425        0.0
# Analytical_score                           -0.035165        0.0
# Joy_score                                   0.053095        0.0
# Fear_score                                 -0.012980        0.0
# Tentative_score                            -0.010880        0.0
# Anger_score                                -0.016700        0.0
# Confident_score                             0.061763        0.0
# word_count                                  0.000161        0.0
# uniqueword_ratio                            0.002557        0.0
# backspace_count                            -0.022383        0.0
# avg_dwelltime                              -0.021248        0.0
# avg_flighttime                             -0.033334        0.0
# stepCount                                   0.077802        0.0
# current_tabCount                            0.009564        0.0
# current_windowCount                         0.026007        0.0
# tabs_activated                              0.022526        0.0
# tabs_created                                0.016347        0.0
# windows_created                            -0.017093        0.0
# productivity_score                         -0.007305        0.0
# phone_unlocks                              -0.032894        0.0
# phone_use_secs                             -0.032823        0.0
#  heart_rate                                -0.024510        0.0
#
#                               relaxing_activity     ...       stepCount  \
# mood                                        0.0     ...        0.111163
# unique_interactions                         0.0     ...        0.094667
# alone                                       0.0     ...       -0.107026
# morale                                      0.0     ...        0.091904
# stress                                      0.0     ...       -0.022510
# fatigue                                     0.0     ...       -0.139097
# compulsions                                 0.0     ...       -0.075882
# getting_ready_activity                      0.0     ...        0.077802
# _activity                                   0.0     ...        0.000000
# relaxing_activity                           0.0     ...        0.000000
# just_woke_up_activity                       0.0     ...        0.000000
# in_class_activity                           0.0     ...        0.056309
# with_k_activity                             0.0     ...       -0.039044
# with_friends_activity                       0.0     ...        0.115589
# chatting_activity                           0.0     ...       -0.004026
# emails_activity                             0.0     ...        0.000000
# leisure_activity                            0.0     ...        0.011074
# with_parents_activity                       0.0     ...        0.000000
# resting_activity                            0.0     ...       -0.032070
# trying_to_leave_apt_activity                0.0     ...        0.000000
# eating_activity                             0.0     ...        0.055668
# therapy_activity                            0.0     ...       -0.012939
# working_out_activity                        0.0     ...       -0.013204
# feedly_activity                             0.0     ...        0.042414
# working_activity                            0.0     ...       -0.043858
# mozfest_activity                            0.0     ...       -0.011363
# ash_stuff_activity                          0.0     ...       -0.027633
# reading_activity                            0.0     ...       -0.045985
# schoolwork_activity                         0.0     ...       -0.067591
# email_activity                              0.0     ...        0.044696
# ...                                         ...     ...             ...
# london_location                             0.0     ...       -0.074809
# library_location                            0.0     ...        0.143183
# hour                                        0.0     ...        0.090621
# avg_attention                               0.0     ...       -0.000218
# avg_engagement                              0.0     ...        0.033690
# avg_valence                                 0.0     ...        0.000326
# blinks                                      0.0     ...        0.118549
# emoji                                       0.0     ...        0.086891
# Sadness_score                               0.0     ...       -0.005473
# Analytical_score                            0.0     ...       -0.054462
# Joy_score                                   0.0     ...        0.084063
# Fear_score                                  0.0     ...        0.001734
# Tentative_score                             0.0     ...        0.003178
# Anger_score                                 0.0     ...        0.028241
# Confident_score                             0.0     ...        0.005389
# word_count                                  0.0     ...        0.035828
# uniqueword_ratio                            0.0     ...        0.004355
# backspace_count                             0.0     ...        0.016317
# avg_dwelltime                               0.0     ...       -0.120185
# avg_flighttime                              0.0     ...       -0.091366
# stepCount                                   0.0     ...        1.000000
# current_tabCount                            0.0     ...        0.003874
# current_windowCount                         0.0     ...       -0.015783
# tabs_activated                              0.0     ...        0.054136
# tabs_created                                0.0     ...       -0.008968
# windows_created                             0.0     ...       -0.066118
# productivity_score                          0.0     ...       -0.078281
# phone_unlocks                               0.0     ...       -0.032242
# phone_use_secs                              0.0     ...        0.022221
#  heart_rate                                 0.0     ...        0.008899
#
#                               current_tabCount  current_windowCount  \
# mood                                  0.097088             0.097914
# unique_interactions                   0.065483             0.083405
# alone                                -0.034602            -0.012526
# morale                                0.109408             0.098744
# stress                                0.519490             0.523248
# fatigue                               0.107679             0.118265
# compulsions                           0.008668             0.007243
# getting_ready_activity                0.009564             0.026007
# _activity                             0.000000             0.000000
# relaxing_activity                     0.000000             0.000000
# just_woke_up_activity                 0.000000             0.000000
# in_class_activity                     0.114092             0.092710
# with_k_activity                      -0.109680            -0.091701
# with_friends_activity                 0.019264             0.019130
# chatting_activity                    -0.116744            -0.092734
# emails_activity                       0.000000             0.000000
# leisure_activity                     -0.127116            -0.128295
# with_parents_activity                 0.000000             0.000000
# resting_activity                      0.008686             0.020234
# trying_to_leave_apt_activity          0.000000             0.000000
# eating_activity                       0.098860             0.108235
# therapy_activity                     -0.034075            -0.032921
# working_out_activity                 -0.034010            -0.032757
# feedly_activity                      -0.081526            -0.071669
# working_activity                      0.096351             0.106601
# mozfest_activity                     -0.043552            -0.009383
# ash_stuff_activity                   -0.159802            -0.149608
# reading_activity                      0.028983             0.016308
# schoolwork_activity                   0.145785             0.079574
# email_activity                        0.045217             0.068463
# ...                                        ...                  ...
# london_location                      -0.169988            -0.073405
# library_location                     -0.043801            -0.058388
# hour                                 -0.001109            -0.001558
# avg_attention                        -0.111585            -0.078877
# avg_engagement                        0.005675            -0.017613
# avg_valence                           0.016579             0.042300
# blinks                                0.096764             0.133395
# emoji                                 0.013368            -0.032670
# Sadness_score                         0.024843             0.067618
# Analytical_score                      0.092303             0.075500
# Joy_score                            -0.122794            -0.081575
# Fear_score                           -0.043845            -0.004632
# Tentative_score                      -0.032670             0.000718
# Anger_score                          -0.061838            -0.055672
# Confident_score                       0.015628             0.003201
# word_count                           -0.036110             0.011501
# uniqueword_ratio                     -0.008384            -0.028873
# backspace_count                      -0.001277             0.023290
# avg_dwelltime                         0.119866             0.077892
# avg_flighttime                        0.011081            -0.054895
# stepCount                             0.003874            -0.015783
# current_tabCount                      1.000000             0.882597
# current_windowCount                   0.882597             1.000000
# tabs_activated                        0.131908             0.162154
# tabs_created                          0.146466             0.162623
# windows_created                       0.122804             0.195246
# productivity_score                    0.093143             0.075929
# phone_unlocks                        -0.130970            -0.116691
# phone_use_secs                       -0.124535            -0.117399
#  heart_rate                          -0.361871            -0.450514
#
#                               tabs_activated  tabs_created  windows_created  \
# mood                                0.027906     -0.001878        -0.040939
# unique_interactions                 0.077002     -0.020348        -0.050563
# alone                              -0.133407      0.000719         0.016758
# morale                              0.051006      0.037564         0.004841
# stress                              0.130175      0.110052         0.124435
# fatigue                             0.050099      0.057976         0.030449
# compulsions                        -0.075840     -0.095406         0.024913
# getting_ready_activity              0.022526      0.016347        -0.017093
# _activity                           0.000000      0.000000         0.000000
# relaxing_activity                   0.000000      0.000000         0.000000
# just_woke_up_activity               0.000000      0.000000         0.000000
# in_class_activity                   0.148730      0.091718        -0.028663
# with_k_activity                    -0.127629     -0.103392        -0.038438
# with_friends_activity               0.017490     -0.064553        -0.026621
# chatting_activity                  -0.048944     -0.027934         0.013358
# emails_activity                     0.000000      0.000000         0.000000
# leisure_activity                   -0.101735     -0.063856        -0.074297
# with_parents_activity               0.000000      0.000000         0.000000
# resting_activity                    0.019127      0.027605        -0.034761
# trying_to_leave_apt_activity        0.000000      0.000000         0.000000
# eating_activity                    -0.004797     -0.040294        -0.025293
# therapy_activity                   -0.038076     -0.036264         0.052417
# working_out_activity                0.014237      0.012040        -0.023114
# feedly_activity                     0.052028      0.063151         0.014272
# working_activity                    0.073722      0.180986         0.017525
# mozfest_activity                   -0.001716     -0.028484        -0.012078
# ash_stuff_activity                 -0.068749     -0.061379         0.001162
# reading_activity                    0.048570      0.020772         0.178505
# schoolwork_activity                 0.084012      0.030591         0.117004
# email_activity                      0.114471      0.059749        -0.018504
# ...                                      ...           ...              ...
# london_location                     0.079889      0.052331         0.018439
# library_location                    0.003835      0.007947        -0.027084
# hour                               -0.084669     -0.035910        -0.084957
# avg_attention                      -0.060880      0.020029        -0.048355
# avg_engagement                      0.034995     -0.006192         0.068804
# avg_valence                        -0.042322      0.027093         0.000169
# blinks                              0.041471      0.058346         0.013559
# emoji                               0.046176     -0.037544        -0.009089
# Sadness_score                      -0.013305     -0.085129         0.031736
# Analytical_score                   -0.007124      0.020891        -0.024680
# Joy_score                           0.109997      0.090620        -0.040172
# Fear_score                         -0.012124      0.040183         0.026981
# Tentative_score                     0.061079     -0.015007         0.019023
# Anger_score                        -0.007633     -0.015160        -0.015808
# Confident_score                    -0.096125     -0.056479        -0.033306
# word_count                          0.141291      0.028636        -0.002915
# uniqueword_ratio                   -0.150354     -0.045592        -0.006629
# backspace_count                     0.108397      0.014465         0.001302
# avg_dwelltime                      -0.080597      0.006727        -0.059739
# avg_flighttime                     -0.148742     -0.124905        -0.005823
# stepCount                           0.054136     -0.008968        -0.066118
# current_tabCount                    0.131908      0.146466         0.122804
# current_windowCount                 0.162154      0.162623         0.195246
# tabs_activated                      1.000000      0.635441         0.265978
# tabs_created                        0.635441      1.000000         0.212103
# windows_created                     0.265978      0.212103         1.000000
# productivity_score                  0.028979     -0.041729         0.084178
# phone_unlocks                      -0.046748     -0.039316        -0.041483
# phone_use_secs                     -0.052965     -0.041132        -0.023806
#  heart_rate                        -0.200421     -0.177155        -0.089542
#
#                               productivity_score  phone_unlocks  \
# mood                                    0.056426      -0.036622
# unique_interactions                    -0.063993       0.012385
# alone                                  -0.132322       0.002791
# morale                                  0.207960      -0.089859
# stress                                  0.106030      -0.129279
# fatigue                                -0.048829       0.116100
# compulsions                             0.010102      -0.046420
# getting_ready_activity                 -0.007305      -0.032894
# _activity                               0.000000       0.000000
# relaxing_activity                       0.000000       0.000000
# just_woke_up_activity                   0.000000       0.000000
# in_class_activity                      -0.025894      -0.028122
# with_k_activity                         0.062269      -0.053032
# with_friends_activity                   0.034874       0.031495
# chatting_activity                      -0.049430       0.063191
# emails_activity                         0.000000       0.000000
# leisure_activity                       -0.238559       0.114719
# with_parents_activity                   0.000000       0.000000
# resting_activity                       -0.083475      -0.021562
# trying_to_leave_apt_activity            0.000000       0.000000
# eating_activity                        -0.006042      -0.060191
# therapy_activity                        0.019520       0.035712
# working_out_activity                   -0.036648      -0.039842
# feedly_activity                        -0.156906       0.017890
# working_activity                       -0.050546      -0.044947
# mozfest_activity                       -0.005892       0.007921
# ash_stuff_activity                     -0.026736       0.043938
# reading_activity                        0.006124      -0.010191
# schoolwork_activity                     0.336620      -0.052471
# email_activity                         -0.058885      -0.063845
# ...                                          ...            ...
# london_location                        -0.079224       0.134795
# library_location                       -0.014863       0.017762
# hour                                   -0.121338       0.030703
# avg_attention                          -0.089049       0.020300
# avg_engagement                         -0.001732       0.026594
# avg_valence                            -0.064660       0.022305
# blinks                                 -0.057514      -0.051479
# emoji                                  -0.032383      -0.018568
# Sadness_score                          -0.010528      -0.006475
# Analytical_score                        0.023963      -0.029788
# Joy_score                               0.003024       0.030022
# Fear_score                             -0.013773       0.070919
# Tentative_score                        -0.049849       0.049471
# Anger_score                            -0.031475       0.020059
# Confident_score                        -0.018240      -0.047908
# word_count                             -0.025216       0.002311
# uniqueword_ratio                       -0.038649       0.034260
# backspace_count                         0.070536      -0.027866
# avg_dwelltime                           0.154015      -0.053103
# avg_flighttime                          0.203384      -0.040255
# stepCount                              -0.078281      -0.032242
# current_tabCount                        0.093143      -0.130970
# current_windowCount                     0.075929      -0.116691
# tabs_activated                          0.028979      -0.046748
# tabs_created                           -0.041729      -0.039316
# windows_created                         0.084178      -0.041483
# productivity_score                      1.000000      -0.111013
# phone_unlocks                          -0.111013       1.000000
# phone_use_secs                          0.030921       0.458920
#  heart_rate                            -0.028609       0.069416
#
#                               phone_use_secs   heart_rate
# mood                                0.002816    -0.191944
# unique_interactions                -0.027687    -0.129654
# alone                               0.006574     0.085990
# morale                             -0.048098    -0.171383
# stress                             -0.093013    -0.339008
# fatigue                             0.097519    -0.006276
# compulsions                         0.003903     0.066405
# getting_ready_activity             -0.032823    -0.024510
# _activity                           0.000000     0.000000
# relaxing_activity                   0.000000     0.000000
# just_woke_up_activity               0.000000     0.000000
# in_class_activity                  -0.012924    -0.167352
# with_k_activity                    -0.045044     0.019069
# with_friends_activity               0.011091    -0.006590
# chatting_activity                   0.059817     0.036489
# emails_activity                     0.000000     0.000000
# leisure_activity                    0.063361     0.095888
# with_parents_activity               0.000000     0.000000
# resting_activity                   -0.032131    -0.081180
# trying_to_leave_apt_activity        0.000000     0.000000
# eating_activity                    -0.020054    -0.112689
# therapy_activity                    0.015401     0.053840
# working_out_activity               -0.001198     0.021981
# feedly_activity                    -0.039162     0.038318
# working_activity                   -0.045984    -0.090834
# mozfest_activity                    0.015745    -0.047732
# ash_stuff_activity                  0.038237     0.076958
# reading_activity                    0.116594     0.006561
# schoolwork_activity                -0.023130     0.026471
# email_activity                     -0.077842    -0.115012
# ...                                      ...          ...
# london_location                     0.026955    -0.123457
# library_location                   -0.017136     0.208308
# hour                               -0.072341     0.040158
# avg_attention                      -0.036312    -0.041304
# avg_engagement                      0.030202     0.062462
# avg_valence                        -0.004336     0.079318
# blinks                             -0.023823    -0.111162
# emoji                               0.017281     0.007947
# Sadness_score                       0.001616     0.043155
# Analytical_score                   -0.029849    -0.060428
# Joy_score                          -0.017114    -0.033521
# Fear_score                         -0.017569    -0.028362
# Tentative_score                     0.018397    -0.028427
# Anger_score                        -0.020430    -0.047366
# Confident_score                     0.040460    -0.029920
# word_count                         -0.045588    -0.047809
# uniqueword_ratio                    0.040169     0.078256
# backspace_count                    -0.078790    -0.096634
# avg_dwelltime                      -0.013598    -0.016566
# avg_flighttime                      0.009298     0.056663
# stepCount                           0.022221     0.008899
# current_tabCount                   -0.124535    -0.361871
# current_windowCount                -0.117399    -0.450514
# tabs_activated                     -0.052965    -0.200421
# tabs_created                       -0.041132    -0.177155
# windows_created                    -0.023806    -0.089542
# productivity_score                  0.030921    -0.028609
# phone_unlocks                       0.458920     0.069416
# phone_use_secs                      1.000000     0.031639
#  heart_rate                         0.031639     1.000000
#
# [86 rows x 86 columns]

# %%
corr.to_csv("correlationmatrix.tsv", sep='\t', encoding='utf-8')

# %%
# create correlation matrix of all variables

import seaborn as sns

cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '30px', 'min-width': '60px', 'min-height': '60px', 'max-height': '60px', 'font-size': '8pt', 'padding': '1em 1em'})\
    .set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col0 {
#             background-color:  #4479bb;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col1 {
#             background-color:  #f2f2f2;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col2 {
#             background-color:  #a4bede;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col3 {
#             background-color:  #df627b;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col4 {
#             background-color:  #d94462;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col5 {
#             background-color:  #de5e77;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col6 {
#             background-color:  #e68699;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col7 {
#             background-color:  #e88ea0;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col8 {
#             background-color:  #e88ea0;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col9 {
#             background-color:  #e88ea0;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col10 {
#             background-color:  #eeaebb;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col11 {
#             background-color:  #eeaebb;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col12 {
#             background-color:  #d8e3f1;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col13 {
#             background-color:  #f0b7c2;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col14 {
#             background-color:  #e88ea0;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col15 {
#             background-color:  #e57d92;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col16 {
#             background-color:  #e88ea0;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col17 {
#             background-color:  #e994a5;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col18 {
#             background-color:  #e88ea0;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col19 {
#             background-color:  #efafbc;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col20 {
#             background-color:  #e88d9f;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col21 {
#             background-color:  #e78a9d;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col22 {
#             background-color:  #e26f86;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col23 {
#             background-color:  #e57f93;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col24 {
#             background-color:  #ec9faf;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col25 {
#             background-color:  #e3788d;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col26 {
#             background-color:  #e68396;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-size:  8pt;
#             padding:  1em 1em;
#         }    #T_a09b168a_f912_11e8_804a_a45e60e2ade9row0_col27 {
#             background-color:  #eca3b1;
#             max-width:  30px;
#             min-width:  60px;
#             min-height:  60px;
#             max-height:  60px;
#             font-

# %%
# get list of variables most and least correlated with mood
corr.mood.sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-83bc34f76d0e> in <module>()
#       1 # get list of variables most and least correlated with mood
# ----> 2 corr.mood.sort_values(ascending=False)
#
# NameError: name 'corr' is not defined

# %%
# get list of variables most and least correlated with stress

corr.stress.sort_values(ascending=False)

# %%
# corr.blinks.sort_values(ascending=False)

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(finalMergedDF["stress"])
plt.show()
